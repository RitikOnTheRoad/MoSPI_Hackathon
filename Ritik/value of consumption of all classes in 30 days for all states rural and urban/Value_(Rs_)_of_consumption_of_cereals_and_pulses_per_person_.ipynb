# %%
# Data used - Value (Rs.) of consumption of cereals and pulses per person

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots

# %%
pip install --upgrade "kaleido==0.1.*"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 MB 13.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

# %%
df=pd.read_excel("/content/Value (Rs.) of consumption of cereals and pulses per person for a period of 30 days for each fractile class of MPCE.xlsx",index_col=[0,1])

# %%
df
# Out:
#                                   Item description   0-5%   5-10%  10-20%  \
# State/UT/All-India Sector
# Andhra Pradesh     Rural                      rice  79.27  113.89  118.65
#                    Rural                wheat/atta  10.50   13.29   17.69
#                    Rural                     jowar   4.80    5.44    3.42
#                    Rural                     bajra   2.05    1.25    0.49
#                    Rural                     maize   0.00    0.00    0.00
# ...                                            ...    ...     ...     ...
# All-India          Urban            peas,chickpeas   0.94    1.34    1.48
#                    Urban              other pulses   0.56    0.73    0.91
#                    Urban                 pulse PDS   0.45    0.71    0.76
#                    Urban      other pulse products   1.38    1.73    2.10
#                    Urban   pulses & pulse products  50.57   56.60   61.93
#
# ...

# %%
# #function to plot all classes vs items.

# def plot_all_class_bar(df,state):
#   fig1=px.bar(df.loc["Rural"].sort_values(by="All Classes",ascending=True),
#         y="Item description",x="All Classes",orientation="h",
#         )
#   fig1.update_layout(title_text=f"Per person value of consumption of cereals and pulses in 30 days in rural {state} ",xaxis_title="Value in Rs",yaxis_title="Item description")

#   fig1.update_traces(
#       hovertemplate="<b>Value in Rs:</b> %{x}<br>"
#                     "<b>Item description:</b> %{y}<br>"
#   )
#   fig1.show()
#   # fig1.write_image(f"{state}_rural.png")
#   # files.download(f"{state}_rural.png")

#   fig2=px.bar(df.loc["Urban"].sort_values(by="All Classes",ascending=True),
#         y="Item description",x="All Classes",orientation="h",
#         )
#   fig2.update_layout(title_text=f"Per person value of consumption of cereals and pulses in 30 days in urban {state} ",xaxis_title="Value in Rs",yaxis_title="Item description")
#   fig2.update_traces(
#       hovertemplate="<b>Value in Rs:</b> %{x}<br>"
#                     "<b>Item description:</b> %{y}<br>"
#   )
#   fig2.show()

#   plt.subplots(rows=1,columns=1)
#   # fig1.write_image(f"{state}_urban.png")
#   # files.download(f"{state}_urban.png")

# %%
#function to plot all classes vs items.

def plot_all_class_bar(df,state):

  fig=make_subplots(rows=1,cols=2,subplot_titles=("Rural","Urban"))


  fig1=px.bar(df.loc["Rural"].sort_values(by="All Classes",ascending=True),
        y="Item description",x="All Classes",orientation="h",
        )


  fig1.update_traces(
      hovertemplate="<b>Value in Rs:</b> %{x}<br>"
                    "<b>Item description:</b> %{y}<br>"
  )

  for traces in fig1.data:
    fig.add_trace(traces,row=1,col=1)



  fig2=px.bar(df.loc["Urban"].sort_values(by="All Classes",ascending=True),
        y="Item description",x="All Classes",orientation="h",
        )

  fig2.update_traces(
      hovertemplate="<b>Value in Rs:</b> %{x}<br>"
                    "<b>Item description:</b> %{y}<br>"
  )

  for traces in fig2.data:
    fig.add_trace(traces,row=1,col=2)

  fig.update_layout(title_text=f"Per person value of consumption of cereals and pulses in 30 days in {state}. ",width=1600,height=600)
  fig.update_xaxes(title_text="Value in Rs",row=1,col=1)
  fig.update_xaxes(title_text="Value in Rs",row=1,col=2)
  fig.update_yaxes(title_text="Item description")
  fig.show()

  fig.write_image(f"{state}.png")
  files.download(f"{state}.png")

# %%
# create an empty dic
# add state name and their respective data frame

dfs={}
state_names=df.index.get_level_values(0).unique()
for state in state_names:
  dfs[state]=df.loc[state]

# %%
import time

# %%
for (name,df) in dfs.items():
 plot_all_class_bar(df,name)
 time.sleep(3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
